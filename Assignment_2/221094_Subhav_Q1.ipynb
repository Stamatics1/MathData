# %% [markdown]
# ** * NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP. * **
#
# # Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# ** Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#plt.show() is used at the end of plotting commands if not using jupyter. I'm using for being explicit.

# %% [markdown]
# ## Exercise 1
#
# ** Follow along with these steps: **
# * ** Create a figure object called fig using plt.figure() **
# * ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,'b')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('title')
ax.set_xlim([0,100])
ax.set_ylim([0,200])
ax.set_yticks([0,50,100,150,200])
# Out:
# [<matplotlib.axis.YTick at 0x1e58082fd90>,
#  <matplotlib.axis.YTick at 0x1e58082d930>,
#  <matplotlib.axis.YTick at 0x1e580613340>,
#  <matplotlib.axis.YTick at 0x1e580b07130>,
#  <matplotlib.axis.YTick at 0x1e580b4ceb0>]

# %% [markdown]
# ## Exercise 2
# ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,0.2,0.2])

# %% [markdown]
# ** Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
ax1.set_xlim([0,100])
ax1.set_ylim([0,200])
ax2.set_xlim([0,100])
ax2.set_ylim([0,200])

ax1.set_yticks([0,50,100,150,200])
ax2.set_yticks([0,50,100,150,200])
ax1.set_xticks([0,20,40,60,80,100])
ax2.set_xticks([0,20,40,60,80,100])

ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax1.plot(x,y,'r')
ax2.plot(x,y,'r')
fig

# %% [markdown]
# ## Exercise 3
#
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig = plt.figure()
axes1 = fig.add_axes([0,0,1,1])
axes2 = fig.add_axes([0.2,0.5,0.4,0.4])

# %% [markdown]
# ** Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
axes1.set_xlim([0,100])
axes1.set_ylim([0,10000])
axes2.set_xlim([20,22])
axes2.set_ylim([30,50])

axes2.set_title('zoom')
axes1.set_xlabel('x')
axes1.set_ylabel('z')
axes2.set_xlabel('x')
axes2.set_ylabel('y')

axes1.plot(x,z,'b')
axes2.plot(x,y,'b')
fig

# %% [markdown]
# ## Exercise 4
#
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fig,axes = plt.subplots(1,2)

# %% [markdown]
# ** Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
axes[0].set_xticks([0,20,40,60,80,100])
axes[0].set_yticks([0,50,100,150,200])
axes[1].set_xticks([0,20,40,60,80,100])
axes[1].set_yticks([0,2000,4000,6000,8000,10000])

axes[0].set_xlim([0,100])
axes[0].set_ylim([0,200])
axes[1].set_xlim([0,100])
axes[1].set_ylim([0,10000])

axes[0].plot(x,y,'b',ls='--')
axes[1].plot(x,z,'r',lw=2)
fig

# %% [markdown]
# ** See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
diag,axes = plt.subplots(1,2,figsize=(10.5,2))

axes[0].set_xticks([0,20,40,60,80,100])
axes[0].set_yticks([0,50,100,150,200])
axes[1].set_xticks([0,20,40,60,80,100])
axes[1].set_yticks([0,2000,4000,6000,8000,10000])

axes[0].set_xlim([0,100])
axes[0].set_ylim([0,200])
axes[1].set_xlim([0,100])
axes[1].set_ylim([0,10000])

axes[0].set_xlabel('x')
axes[0].set_ylabel('y')
axes[1].set_xlabel('x')
axes[1].set_ylabel('z')

axes[0].plot(x,y,'b',lw=3)
axes[1].plot(x,z,'r',lw=2,ls='--')

# %% [markdown]
# # Great Job!
