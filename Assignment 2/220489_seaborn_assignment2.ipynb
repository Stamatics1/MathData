# %% [markdown]
# # Seaborn Exercises

# %% [markdown]
# ## The Data

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# ** Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
jp=sns.jointplot(x='fare',y='age',data=titanic,kind='scatter', xlim=(-100, 600),color='#4C72B0',edgecolor='none')

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
ax = sns.histplot(titanic['fare'], kde=False, bins=30,color='#FF9999',edgecolor='#E0A9A9')
ax.set_ylabel('')
ax.set_xlim(left=0)
ax.set_ylim(bottom=0)
ax.set_xlim(left=0, right=600)
ax.set_ylim(bottom=0, top=500)
plt.show()

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
sns.boxplot(x='class', y='age', data=titanic, palette='rainbow')
plt.ylim([0,80])
# Out:
# (0.0, 80.0)

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

sns.swarmplot(x='class', y='age', data=titanic, palette='Set2')
plt.ylim([-10,90])
# Out:
# C:\Users\jyoti\AppData\Local\Temp\ipykernel_13880\1039336667.py:6: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x='class', y='age', data=titanic, palette='Set2')
# (-10.0, 90.0)
# C:\Users\jyoti\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
sns.countplot(x='sex',data=titanic, palette=['#5975A4','#5F9E6E'])
plt.ylim([0,600])
# Out:
# (0.0, 600.0)

# %%
heatmap = sns.heatmap(titanic.corr(numeric_only=True), cmap='coolwarm', vmin=-1, vmax=1)
plt.title('titanic.corr()')
cbar = heatmap.collections[0].colorbar
cbar.set_ticks([-0.8, -0.4, 0.0, 0.4, 0.8])
cbar.set_ticklabels(['-0.8', '-0.4', '0.0', '0.4', '0.8'])
plt.xticks(rotation=0)

plt.show()

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
g = sns.FacetGrid(data=titanic,col='sex')
g.map(plt.hist, 'age', edgecolor='#36527E', color='#4C72B0')
plt.xlim([0,80])
plt.ylim([0,120])
# Out:
# (0.0, 120.0)

# %% [markdown]
# # Great Job!
#
# ### That is it for now! We'll see a lot more of seaborn practice problems in the machine learning section!
