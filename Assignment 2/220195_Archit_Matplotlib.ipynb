# %% [markdown]
# ** * NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP. * **
#
# # Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# ** Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.show()

# %% [markdown]
# ## Exercise 1
#
# ** Follow along with these steps: **
# * ** Create a figure object called fig using plt.figure() **
# * ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])

ax.plot(x, y)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Plot of y = x*2')

plt.show()

# %% [markdown]
# ## Exercise 2
# ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
ax1 = fig.add_axes([0, 0, 1, 1])

ax2 = fig.add_axes([0.2, 0.5, 0.2, 0.2])

ax1.plot(x, y)
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_title('Plot on ax1')

ax2.plot(x, y)
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_title('Plot on ax2')

plt.show()

# %% [markdown]
# ** Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
ax1 = fig.add_axes([0, 0, 1,1])
ax2 = fig.add_axes([0.2, 0.5, 0.2, 0.2])

ax1.plot(x, y)
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_title('Plot on ax1')

ax2.plot(x, y)
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_title('Plot on ax2')
fig.show()
# Out:
# C:\Users\91840\AppData\Local\Temp\ipykernel_11744\475598744.py:13: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Exercise 3
#
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %% [markdown]
# ** Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.2, 0.5, 0.4, 0.4])
ax1.plot(x, y)
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_title('y = x*2')
ax2.plot(x, z)
ax2.set_xlabel('x')
ax2.set_ylabel('z')
ax2.set_title('z = x**2')

# %% [markdown]
# ## Exercise 4
#
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x, y)
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')
axes[0].set_title('y = x*2')
axes[1].plot(x, z)
axes[1].set_xlabel('x')
axes[1].set_ylabel('z')
axes[1].set_title('z = x**2')
plt.tight_layout()
plt.show()

# %% [markdown]
# ** Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

axes[0].plot(x, y, linewidth=3, linestyle='-.', label='y = x*2')
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')
axes[0].set_title('Plot of y = x*2')
axes[0].legend()

axes[1].plot(x, z, linewidth=5, linestyle=':', label='z = x**2')
axes[1].set_xlabel('x')
axes[1].set_ylabel('z')
axes[1].set_title('Plot of z = x**2')
axes[1].legend()

plt.tight_layout()

plt.show()

# %% [markdown]
# ** See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

axes[0].plot(x, y, linewidth=2, linestyle='--', label='y = x*2')
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')
axes[0].set_title('Plot of y = x*2')
axes[0].legend()

axes[1].plot(x, z, linewidth=3, linestyle=':', label='z = x**2')
axes[1].set_xlabel('x')
axes[1].set_ylabel('z')
axes[1].set_title('Plot of z = x**2')
axes[1].legend()

plt.tight_layout()

plt.show()

# %% [markdown]
# # Great Job!
