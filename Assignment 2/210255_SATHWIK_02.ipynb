# %% [markdown]
# # Seaborn Exercises

# %% [markdown]
# ## The Data

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# ** Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
jointPlot = sns.jointplot(data=titanic, x='fare', y='age', kind='scatter', height=6)
jointPlot.ax_joint.set_xlim(-100, 600)  # Set x-axis limits
# Out:
# (-100.0, 600.0)

# %%
bins = [0, 100, 200, 300, 400, 500, 600]

ax = sns.histplot(data=titanic, x='fare', bins=bins, color ='')
ax.set_xlim(0,600)
ax.set_ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
ax = sns.boxplot(data=titanic, x='class', y='age')
ax.set_ylim(0,80)
# Out:
# (0.0, 80.0)

# %%
sns.swarmplot(data=titanic, x='class', y='age', hue = 'class', legend = False)
# Out:
# <Axes: xlabel='class', ylabel='age'>
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.countplot(data=titanic, x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
correlation_matrix = titanic.corr()
sns.heatmap(data=correlation_matrix, annot=False, cmap='coolwarm')
# Out:
# <ipython-input-20-9b789cb7a84a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = titanic.corr()
# <Axes: >

# %%
g = sns.FacetGrid(data=titanic, col='sex', col_wrap=2)
g.map(sns.histplot, 'age')

# %% [markdown]
# # Great Job!
#
# ### That is it for now! We'll see a lot more of seaborn practice problems in the machine learning section!
