# %% [markdown]
# # Seaborn Exercises

# %% [markdown]
# ## The Data

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# ** Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
sns.jointplot(data=titanic, y='age', x='fare', kind='scatter')

plt.ylabel('Age')
plt.xlabel('Fare')

plt.show()

# %%
fig, ax = plt.subplots()

ax.hist(titanic['fare'], bins=10)

ax.set_xlabel('Fare')

plt.show()

# %%
sns.boxplot(data=titanic, x='class', y='age')

plt.xlabel('Class')
plt.ylabel('Age')

plt.show()

# %%
sns.swarmplot(data=titanic, x='class', y='age')

plt.xlabel('Class')
plt.ylabel('Age')

plt.show()
# Out:
# C:\Users\Swastika\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 11.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.countplot(data=titanic, x='sex')

plt.xlabel('Sex')

plt.show()

# %%
selected_vars = ['survived', 'pclass', 'age', 'sibsp', 'parch', 'fare', 'adult_male', 'alone']
selected_df = titanic[selected_vars]

vmin = -0.8
vmax = 0.8

corr_matrix = selected_df.corr()
sns.heatmap(corr_matrix, vmin=vmin, vmax=vmax, cmap='coolwarm')

plt.show()

# %%
g = sns.FacetGrid(titanic, col="sex")

g.map(plt.hist, "age")

plt.tight_layout()

plt.show()

# %% [markdown]
# # Great Job!
#
# ### That is it for now! We'll see a lot more of seaborn practice problems in the machine learning section!
